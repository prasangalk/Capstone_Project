# %% [markdown]
# # **API Test Code**

# %%
import requests

url = "http://127.0.0.1:5001/regressor"


payload = {'age': 42.451275,
     'sex': 'male',
     'bmi': 24.273893,
     'smoker': 'no',
     'region': 'southeast',
     'children': 5}    

headers = {}

files=[

]

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
